# %%
print("Olá mundo")

# print exibirá informações na tela
print("Sejam todos bem vindos ao python simplificado")

"""
Aprendendo a programar em python
abaixo irá mostrar uma soma
"""

print(4+6)
# Out:
# Olá mundo
# Sejam todos bem vindos ao python simplificado
# 10

# %%
# aual_6 variáveis I

"""
Variáveis é como uma caixa, com um nome, onde 

"""
